# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
PATH = os.getenv('HOME') + '/data/'
PATH
# Out:
# '/Users/taekkim/data/'

# %%
df = pd.read_csv(PATH + 'EPL Standings 2010-2021.csv')
df
# Out:
#       Season  Pos                    Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 0    2010-11    1       Manchester United   38  23  11   4  78  37  41   80
# 1    2010-11    2                 Chelsea   38  21   8   9  69  33  36   71
# 2    2010-11    3         Manchester City   38  21   8   9  60  33  27   71
# 3    2010-11    4                 Arsenal   38  19  11   8  72  43  29   68
# 4    2010-11    5       Tottenham Hotspur   38  16  14   8  55  46   9   62
# ..       ...  ...                     ...  ...  ..  ..  ..  ..  ..  ..  ...
# 215  2020-21   16  Brighton & Hove Albion   38   9  14  15  40  46  -6   41
# 216  2020-21   17                 Burnley   38  10   9  19  33  55 -22   39
# 217  2020-21   18                  Fulham   38   5  13  20  27  53 -26   28
# 218  2020-21   19    West Bromwich Albion   38   5  11  22  35  76 -41   26
# 219  2020-21   20        Sheffield United   38   7   2  29  20  63 -43   23
#
#                            Qualification or relegation
# ...

# %%
df['Team'].value_counts()
# Out:
# Manchester United          11
# Manchester City            11
# Arsenal                    11
# Tottenham Hotspur          11
# Liverpool                  11
# Everton                    11
# Chelsea                    11
# Newcastle United           10
# West Ham United            10
# Southampton                 9
# West Bromwich Albion        9
# Stoke City                  8
# Crystal Palace              8
# Aston Villa                 8
# Leicester City              7
# Sunderland                  7
# Swansea City                7
# Burnley                     6
# Fulham                      6
# Norwich City                5
# Watford                     5
# Wolverhampton Wanderers     5
# Bournemouth                 5
# Brighton & Hove Albion      4
# Queens Park Rangers         3
# Hull City                   3
# Wigan Athletic              3
# Sheffield United            2
# Huddersfield Town           2
# Cardiff City                2
# Blackburn Rovers            2
# ...

# %%
Teams = ['Manchester United', 'Manchester City', 'Arsenal',
         'Tottenham Hotspur', 'Liverpool', 'Everton',
         'Chelsea']
Teams = sorted(Teams)
Teams
# Out:
# ['Arsenal',
#  'Chelsea',
#  'Everton',
#  'Liverpool',
#  'Manchester City',
#  'Manchester United',
#  'Tottenham Hotspur']

# %%
df = df[df['Team'].isin(Teams)].sort_values(by=['Team', 'Season'],ascending='True')
df
# Out:
#       Season  Pos               Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 3    2010-11    4            Arsenal   38  19  11   8  72  43  29   68
# 22   2011-12    3            Arsenal   38  21   7  10  74  49  25   70
# 43   2012-13    4            Arsenal   38  21  10   7  72  37  35   73
# 63   2013-14    4            Arsenal   38  24   7   7  68  41  27   79
# 82   2014-15    3            Arsenal   38  22   9   7  71  36  35   75
# ..       ...  ...                ...  ...  ..  ..  ..  ..  ..  ..  ...
# 121  2016-17    2  Tottenham Hotspur   38  26   8   4  86  26  60   86
# 142  2017-18    3  Tottenham Hotspur   38  23   8   7  74  36  38   77
# 163  2018-19    4  Tottenham Hotspur   38  23   2  13  67  39  28   71
# 185  2019-20    6  Tottenham Hotspur   38  16  11  11  61  47  14   59
# 206  2020-21    7  Tottenham Hotspur   38  18   8  12  68  45  23   62
#
#                            Qualification or relegation
# 3    Qualification for the Champions League play-of...
# ...

# %%
teams_win = df.groupby('Team')['W'].sum()
teams_win
# Out:
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/2495872843.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Teams, rotation=90)

# %%
teams_draw = df.groupby('Team')['D'].sum()
teams_loss = df.groupby('Team')['L'].sum()

# %%
plt.close()

# %%
fig, ax = plt.subplots()
ax.bar(Teams, teams_win, label='win')
ax.bar(Teams, teams_draw, bottom=teams_win, label='draw')
ax.bar(Teams, teams_loss, bottom=teams_draw+teams_win, label='loss')
ax.set_xticklabels(Teams, rotation=90)
ax.set_ylabel('Number of wins')
plt.title('2010-21 EPL W/D/L')
plt.legend()
plt.show()
# Out:
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/2046747960.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Teams, rotation=90)

# %%
df = pd.read_csv(PATH + 'EPL Standings 2010-2021.csv')
df
# Out:
#       Season  Pos                    Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 0    2010-11    1       Manchester United   38  23  11   4  78  37  41   80
# 1    2010-11    2                 Chelsea   38  21   8   9  69  33  36   71
# 2    2010-11    3         Manchester City   38  21   8   9  60  33  27   71
# 3    2010-11    4                 Arsenal   38  19  11   8  72  43  29   68
# 4    2010-11    5       Tottenham Hotspur   38  16  14   8  55  46   9   62
# ..       ...  ...                     ...  ...  ..  ..  ..  ..  ..  ..  ...
# 215  2020-21   16  Brighton & Hove Albion   38   9  14  15  40  46  -6   41
# 216  2020-21   17                 Burnley   38  10   9  19  33  55 -22   39
# 217  2020-21   18                  Fulham   38   5  13  20  27  53 -26   28
# 218  2020-21   19    West Bromwich Albion   38   5  11  22  35  76 -41   26
# 219  2020-21   20        Sheffield United   38   7   2  29  20  63 -43   23
#
#                            Qualification or relegation
# ...

# %%
winner = df[df['Pos'] == 1].sort_values(by=['Season'])
winner
# Out:
#       Season  Pos               Team  Pld   W   D  L   GF  GA  GD  Pts  \
# 0    2010-11    1  Manchester United   38  23  11  4   78  37  41   80
# 20   2011-12    1    Manchester City   38  28   5  5   93  29  64   89
# 40   2012-13    1  Manchester United   38  28   5  5   86  43  43   89
# 60   2013-14    1    Manchester City   38  27   5  6  102  37  65   86
# 80   2014-15    1            Chelsea   38  26   9  3   73  32  41   87
# 100  2015-16    1     Leicester City   38  23  12  3   68  36  32   81
# 120  2016-17    1            Chelsea   38  30   3  5   85  33  52   93
# 140  2017-18    1    Manchester City   38  32   4  2  106  27  79  100
# 160  2018-19    1    Manchester City   38  32   2  4   95  23  72   98
# 180  2019-20    1          Liverpool   38  32   3  3   85  33  52   99
# 200  2020-21    1    Manchester City   38  27   5  6   83  32  51   86
#
#                            Qualification or relegation
# 0    Qualification for the Champions League group s...
# ...

# %%
runner_up = df[df['Pos'] == 2].sort_values(by=['Season'])
runner_up
# Out:
#       Season  Pos               Team  Pld   W   D  L   GF  GA  GD  Pts  \
# 1    2010-11    2            Chelsea   38  21   8  9   69  33  36   71
# 21   2011-12    2  Manchester United   38  28   5  5   89  33  56   89
# 41   2012-13    2    Manchester City   38  23   9  6   66  34  32   78
# 61   2013-14    2          Liverpool   38  26   6  6  101  50  51   84
# 81   2014-15    2    Manchester City   38  24   7  7   83  38  45   79
# 101  2015-16    2            Arsenal   38  20  11  7   65  36  29   71
# 121  2016-17    2  Tottenham Hotspur   38  26   8  4   86  26  60   86
# 141  2017-18    2  Manchester United   38  25   6  7   68  28  40   81
# 161  2018-19    2          Liverpool   38  30   7  1   89  22  67   97
# 181  2019-20    2    Manchester City   38  26   3  9  102  35  67   81
# 201  2020-21    2  Manchester United   38  21  11  6   73  44  29   74
#
#                            Qualification or relegation
# 1    Qualification for the Champions League group s...
# ...

# %%
fig, ax = plt.subplots()
ax.hist(winner['Pts'], label='Winner', bins=10, histtype='step')
ax.hist(runner_up['Pts'], label='Runner up', bins=10, histtype='step')
ax.set_xlabel('Pts')
ax.set_ylabel('Number of teams')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(winner['Pts'], label='Winner', bins=10, alpha=0.5)
ax.hist(runner_up['Pts'], label='Runner up', bins=10, alpha=0.5)
ax.set_xlabel('Pts')
ax.set_ylabel('Number of teams')
plt.legend()
plt.show()

# %%
df_copy = df.copy()
df = df.sort_values(by=['Season', 'Pts'], ascending=[True, False])
df
# Out:
#       Season  Pos                    Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 0    2010-11    1       Manchester United   38  23  11   4  78  37  41   80
# 1    2010-11    2                 Chelsea   38  21   8   9  69  33  36   71
# 2    2010-11    3         Manchester City   38  21   8   9  60  33  27   71
# 3    2010-11    4                 Arsenal   38  19  11   8  72  43  29   68
# 4    2010-11    5       Tottenham Hotspur   38  16  14   8  55  46   9   62
# ..       ...  ...                     ...  ...  ..  ..  ..  ..  ..  ..  ...
# 215  2020-21   16  Brighton & Hove Albion   38   9  14  15  40  46  -6   41
# 216  2020-21   17                 Burnley   38  10   9  19  33  55 -22   39
# 217  2020-21   18                  Fulham   38   5  13  20  27  53 -26   28
# 218  2020-21   19    West Bromwich Albion   38   5  11  22  35  76 -41   26
# 219  2020-21   20        Sheffield United   38   7   2  29  20  63 -43   23
#
#                            Qualification or relegation
# ...

# %%
gf_mean = df.groupby('Season')['GF'].mean()
pts_mean = df.groupby('Season')['Pts'].mean()
df.groupby('Season')['GF'].mean()
# Out:
# Season
# 2010-11    53.15
# 2011-12    53.30
# 2012-13    53.15
# 2013-14    52.60
# 2014-15    48.75
# 2015-16    51.30
# 2016-17    53.20
# 2017-18    50.90
# 2018-19    53.60
# 2019-20    51.70
# 2020-21    51.20
# Name: GF, dtype: float64

# %%
gf_std = df.groupby('Season')['GF'].std()
pts_std = df.groupby('Season')['Pts'].std()
df.groupby('Season')['GF'].std()
# Out:
# Season
# 2010-11    10.599280
# 2011-12    16.134631
# 2012-13    14.758673
# 2013-14    20.615273
# 2014-15    14.767942
# 2015-16    13.163346
# 2016-17    18.529067
# 2017-18    20.968397
# 2018-19    18.071204
# 2019-20    18.809572
# 2020-21    16.728796
# Name: GF, dtype: float64

# %%
winner.std(axis=0)
# Out:
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/2081953194.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   winner.std(axis=0)
# Pos     0.000000
# Pld     0.000000
# W       3.286335
# D       3.341203
# L       1.328020
# GF     11.611123
# GA      5.430553
# GD     14.593274
# Pts     6.911124
# dtype: float64

# %%
fig, ax = plt.subplots()

ax.errorbar(winner['Season'], gf_mean, yerr=gf_std/50, label='GF')
ax.errorbar(runner_up['Season'], pts_mean, yerr=pts_std/50, label='PTS')
ax.set_xticklabels(winner['Season'], rotation=90)
plt.legend()
plt.title('Seasonal mean GF & PTS of every teams')
plt.show()
# Out:
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/2670732771.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(winner['Season'], rotation=90)

# %%
fig, ax = plt.subplots()
ax.boxplot([winner['Pts'],runner_up['Pts']])
ax.set_xticklabels(['Winner','Runner-up'])
ax.set_ylabel('Pts')
plt.show()

# %%
before_16 = df[df['Season']<'2016-17']
before_16

# %%
after_16 = df[df['Season']>='2016-17']
after_16
# Out:
#       Season  Pos                    Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 120  2016-17    1                 Chelsea   38  30   3   5  85  33  52   93
# 121  2016-17    2       Tottenham Hotspur   38  26   8   4  86  26  60   86
# 122  2016-17    3         Manchester City   38  23   9   6  80  39  41   78
# 123  2016-17    4               Liverpool   38  22  10   6  78  42  36   76
# 124  2016-17    5                 Arsenal   38  23   6   9  77  44  33   75
# ..       ...  ...                     ...  ...  ..  ..  ..  ..  ..  ..  ...
# 215  2020-21   16  Brighton & Hove Albion   38   9  14  15  40  46  -6   41
# 216  2020-21   17                 Burnley   38  10   9  19  33  55 -22   39
# 217  2020-21   18                  Fulham   38   5  13  20  27  53 -26   28
# 218  2020-21   19    West Bromwich Albion   38   5  11  22  35  76 -41   26
# 219  2020-21   20        Sheffield United   38   7   2  29  20  63 -43   23
#
#                            Qualification or relegation
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(before_16['Pts'], before_16['Pos'], color='b', label='Before 16-17')
ax.scatter(after_16['Pts'], after_16['Pos'], color='r', label='After 16-17')
ax.set_xlabel("Pts")
ax.set_ylabel("Rank")
ax.set_yticks([1,5,10,15,20])
plt.gca().invert_yaxis()
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(df['Pts'], df['Pos'], c=df['Season'].index)
ax.set_xlabel("Pts")
ax.set_ylabel("Rank")
ax.set_yticks([1,5,10,15,20])
plt.gca().invert_yaxis()
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(Teams, teams_win, label='win')
ax.bar(Teams, teams_draw, bottom=teams_win, label='draw')
ax.bar(Teams, teams_loss, bottom=teams_draw+teams_win, label='loss')
ax.set_xticklabels(Teams, rotation=90)
ax.set_ylabel('Number of W/D/L')
plt.title('2010-21 EPL Wins/Draws/Losses')
plt.legend()
plt.show()
# Out:
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/345607700.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Teams, rotation=90)

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.bar(Teams, teams_win, label='win')
ax.bar(Teams, teams_draw, bottom=teams_win, label='draw')
ax.bar(Teams, teams_loss, bottom=teams_draw+teams_win, label='loss')
ax.set_xticklabels(Teams, rotation=90)
ax.set_ylabel('Number of W/D/L')
plt.title('2010-21 EPL Wins/Draws/Losses')
plt.legend()
plt.show()
# Out:
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/1609067114.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Teams, rotation=90)

# %%
plt.style.use('default')
fig, ax = plt.subplots()
ax.bar(Teams, teams_win, label='win')
ax.bar(Teams, teams_draw, bottom=teams_win, label='draw')
ax.bar(Teams, teams_loss, bottom=teams_draw+teams_win, label='loss')
ax.set_xticklabels(Teams, rotation=90)
ax.set_ylabel('Number of W/D/L')
plt.title('2010-21 EPL Wins/Draws/Losses')
plt.legend()
plt.show()
# Out:
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/2012071326.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Teams, rotation=90)

# %%
plt.style.use('seaborn-pastel')
fig, ax = plt.subplots()
ax.bar(Teams, teams_win, label='win')
ax.bar(Teams, teams_draw, bottom=teams_win, label='draw')
ax.bar(Teams, teams_loss, bottom=teams_draw+teams_win, label='loss')
ax.set_xticklabels(Teams, rotation=90)
ax.set_ylabel('Number of W/D/L')
plt.title('2010-21 EPL Wins/Draws/Losses')
plt.legend()
plt.show()
# Out:
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/369844150.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Teams, rotation=90)

# %%
fig.savefig('epl_WDL.jpg')
fig.savefig('epl_WDL_qual_50.jpg', quality=50)
fig.savefig('epl_WDL_dpi_300.jpg', dpi=300)
# Out:
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/401249062.py:2: MatplotlibDeprecationWarning:
# The 'quality' parameter of print_jpg() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use pil_kwargs={'quality': ...} instead. If any parameter follows 'quality', they should be passed as keyword, not positionally.
#   fig.savefig('epl_WDL_qual_50.jpg', quality=50)

# %%
df.columns
# Out:
# Index(['Season', 'Pos', 'Team', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts',
#        'Qualification or relegation'],
#       dtype='object')

# %%
teams = list(df.groupby('Team').groups.keys())
mean_pts = df.groupby('Team')['Pts'].mean()
std_pts = df.groupby('Team')['Pts'].std()

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots()
for team, mean, std in zip(teams, mean_pts, std_pts):
    ax.bar(team, mean, yerr=std)
ax.set_ylabel('Pts')
ax.set_xticklabels(teams, rotation=90)
plt.title('EPL 10-21 average pts of all teams')
plt.show()
# Out:
# /Users/taekkim/.conda/envs/aiffel/lib/python3.9/site-packages/matplotlib/axes/_base.py:2283: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# /var/folders/z_/fl1l3lj16n55t2wwqw4xkcw80000gn/T/ipykernel_83585/1395248531.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(teams, rotation=90)

# %%
# %matplotlib inline
sns.relplot(x='GF',y='Pts',hue='Team',size='Pos',sizes=(400,40),
           alpha=.5, palette='muted', height=6, data=df)
