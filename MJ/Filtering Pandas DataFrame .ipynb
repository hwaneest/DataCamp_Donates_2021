# %% [markdown]
# # Filtering Pandas DataFrame

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 데이터 불러오기

# %%
df = pd.read_csv("Downloads/disney_plus_titles.csv")
df
# Out:
#      show_id     type                           title  \
# 0         s1    Movie                   A Spark Story
# 1         s2    Movie                  Spooky Buddies
# 2         s3    Movie          The Fault in Our Stars
# 3         s4  TV Show                 Dog: Impossible
# 4         s5  TV Show  Spidey And His Amazing Friends
# ...      ...      ...                             ...
# 1363   s1364    Movie          The Sword in the Stone
# 1364   s1365    Movie                 Those Calloways
# 1365   s1366  TV Show            Disney Kirby Buckets
# 1366   s1367  TV Show                  Disney Mech-X4
# 1367   s1368  TV Show              Imagination Movers
#
#                         director  \
# 0     Jason Sterman, Leanne Dare
# 1                   Robert Vince
# 2                     Josh Boone
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1363         Wolfgang Reitherman
# 1364                Norman Tokar
# 1365                         NaN
# 1366                         NaN
# 1367                         NaN
#
#                                                    cast  \
# 0                         Apthon Corbin, Louis Gonzales
# 1     Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...
# 2     Shailene Woodley, Ansel Elgort, Laura Dern, Sa...
# 3                                          Matt Beisner
# 4     Benjamin Valic, Lily Sanfelippo, Jakari Fraser...
# ...                                                 ...
# 1363  Sebastian Cabot, Karl Swenson, Rickie Sorensen...
# 1364  Brian Keith, Vera Miles, Brandon de Wilde, Wal...
# 1365  Jacob Bertrand, Mekai Curtis, Cade Sutton, Oli...
# 1366  Nathaniel Potvin, Raymond Cham, Kamran Lucas, ...
# 1367  Rich Collins, Dave Poche, Scott Durbin, Scott ...
#
#                     country          date_added  release_year rating  \
# 0                       NaN  September 24, 2021          2021  TV-PG
# 1     United States, Canada  September 24, 2021          2011      G
# 2             United States  September 24, 2021          2014  PG-13
# 3             United States  September 22, 2021          2019  TV-PG
# 4             United States  September 22, 2021          2021   TV-Y
# ...                     ...                 ...           ...    ...
# 1363          United States     October 1, 2019          1963      G
# 1364          United States     October 1, 2019          1965     PG
# 1365          United States                 NaN          2014  TV-Y7
# 1366                 Canada                 NaN          2016  TV-Y7
# 1367          United States                 NaN          2008   TV-Y
#
#        duration                                  listed_in  \
# 0        88 min                                Documentary
# 1        93 min                      Comedy, Fantasy, Kids
# 2       127 min              Coming of Age, Drama, Romance
# 3     2 Seasons       Animals & Nature, Docuseries, Family
# 4      1 Season          Action-Adventure, Animation, Kids
# ...         ...                                        ...
# 1363     80 min        Action-Adventure, Animation, Comedy
# 1364    132 min            Animals & Nature, Drama, Family
# 1365  3 Seasons    Action-Adventure, Comedy, Coming of Age
# 1366  2 Seasons  Action-Adventure, Comedy, Science Fiction
# 1367  3 Seasons                                Kids, Music
#
#                                             description
# 0     Two Pixar filmmakers strive to bring their uni...
# 1     The puppies go on a spooky adventure through a...
# 2     Hazel and Gus share a love that sweeps them on...
# 3     Matt Beisner uses unique approaches to modifyi...
# 4     Spidey teams up with pals to become The Spidey...
# ...                                                 ...
# 1363  Merlin trains a young orphan who's destined to...
# 1364  A strong-willed family struggles to establish ...
# 1365   Welcome to Kirby's world! It's rude and sketchy.
# 1366  Ryan discovers his ability to control a giant ...
# 1367  Rock out with the Imagination Movers, Disney J...
#
# [1368 rows x 12 columns]

# %% [markdown]
# #### isna( ) 함수를 통해 Null 값 확인

# %%
df.isna().mean()
# Out:
# show_id         0.000000
# type            0.000000
# title           0.000000
# director        0.321637
# cast            0.127193
# country         0.127924
# date_added      0.002193
# release_year    0.000000
# rating          0.001462
# duration        0.000000
# listed_in       0.000000
# description     0.000000
# dtype: float64

# %% [markdown]
# #### dropna( ) 함수를 통해 Null 값 제거

# %%
# null 값 제거 
df.dropna(inplace =True, axis=0)
df.isna().mean()
# Out:
# show_id         0.0
# type            0.0
# title           0.0
# director        0.0
# cast            0.0
# country         0.0
# date_added      0.0
# release_year    0.0
# rating          0.0
# duration        0.0
# listed_in       0.0
# description     0.0
# dtype: float64

# %% [markdown]
# ### 단일조건 필터링
# *   DataFrame명[ DataFrame명 ['칼럼명']   값]

# %%
year = df['release_year'] >2020
df[year].head(1)
# Out:
#    show_id   type             title       director  \
# 19     s20  Movie  Twenty Something  Aphton Corbin
#
#                                                  cast        country  \
# 19  Kaylin Price, Ariana Brown, Aliyah Taylor, Jan...  United States
#
#             date_added  release_year rating duration          listed_in  \
# 19  September 10, 2021          2021     PG   11 min  Animation, Family
#
#                                           description
# 19  Adulting is hard. One day you're nailing it, t...

# %%
df[df['release_year'] > 2020].tail(1)
# Out:
#     show_id   type            title   director  \
# 214    s215  Movie  Flora & Ulysses  Lena Khan
#
#                                                   cast        country  \
# 214  Matilda Lawler, Alyson Hannigan, Ben Schwartz,...  United States
#
#             date_added  release_year rating duration  \
# 214  February 19, 2021          2021     PG   95 min
#
#                         listed_in  \
# 214  Comedy, Coming of Age, Drama
#
#                                            description
# 214  Comic book fan Flora saves a squirrel whose su...

# %% [markdown]
# ### 복합조건 필터링
# * Numpy variants 사용 - np.logical_and , np.logical_or , np.logical_not

# %%
df[np.logical_and(df['country'] == 'United States', df['release_year'] > 2020 )].head(2)
# Out:
#    show_id   type                                            title  \
# 19     s20  Movie                                 Twenty Something
# 24     s25  Movie  Happier Than Ever: A Love Letter to Los Angeles
#
#                              director  \
# 19                      Aphton Corbin
# 24  Robert Rodriguez, Patrick Osborne
#
#                                                  cast        country  \
# 19  Kaylin Price, Ariana Brown, Aliyah Taylor, Jan...  United States
# 24                             Billie Eilish, FINNEAS  United States
#
#             date_added  release_year rating duration            listed_in  \
# 19  September 10, 2021          2021     PG   11 min    Animation, Family
# 24   September 3, 2021          2021  TV-14   66 min  Concert Film, Music
#
#                                           description
# 19  Adulting is hard. One day you're nailing it, t...
# 24  Billie Eilish makes her Disney+ debut with "Ha...

# %% [markdown]
# ### & 사용
# DataFrame명[(DataFrame명['칼럼명1'] 값) & (DataFrame명['칼럼명2']  값)]

# %%
 df[(df['country'] == 'United Kingdom' ) &  (df['release_year'] >2018)].tail(2)
# Out:
#      show_id   type                                 title          director  \
# 539     s540  Movie                  Viking Warrior Women  Stuart Strickson
# 1229   s1230  Movie  The Lost Tomb of Alexander the Great      Duncan Singh
#
#                  cast         country         date_added  release_year rating  \
# 539   Ella Al-Shamahi  United Kingdom  February 28, 2020          2019  TV-PG
# 1229  Matt McFetridge  United Kingdom  November 12, 2019          2019  TV-PG
#
#      duration                listed_in  \
# 539    44 min  Documentary, Historical
# 1229   44 min  Documentary, Historical
#
#                                             description
# 539   New discoveries challenge everything we though...
# 1229  An archaeologist on the hunt for Alexander the...

# %% [markdown]
# ### Query 함수 사용 필터링
# * 조건에 부합하는 데이터 추출
# * 문법 사용 예
#   DataFrame.query('(a < b) & (b < c) ')
#   DataFrame.query(' a < b  &  b < c' )
#   DataFrame.query(' a < b  and b < c')
#   DataFrame.query(' a < b < c ')

# %%
df.query('release_year > 2019  & release_year > 2020 ').tail(2)
# Out:
#     show_id   type                title     director  \
# 207    s208  Movie  Myth: A Frozen Tale  Jeff Gipson
# 214    s215  Movie      Flora & Ulysses    Lena Khan
#
#                                                   cast        country  \
# 207                                   Evan Rachel Wood  United States
# 214  Matilda Lawler, Alyson Hannigan, Ben Schwartz,...  United States
#
#             date_added  release_year rating duration  \
# 207  February 26, 2021          2021   TV-G   12 min
# 214  February 19, 2021          2021     PG   95 min
#
#                         listed_in  \
# 207    Animation, Family, Fantasy
# 214  Comedy, Coming of Age, Drama
#
#                                            description
# 207  A family sits down for a bedtime story and is ...
# 214  Comic book fan Flora saves a squirrel whose su...
