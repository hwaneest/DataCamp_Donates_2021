# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')

import matplotlib
matplotlib.rc('font', family='AppleGothic')
matplotlib.rc('axes', unicode_minus=False)

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# 그래프 틀 변경
plt.rcParams['axes.unicode_minus'] = False
sns.set(font_scale = 1)  
plt.style.use(['fivethirtyeight'])
pd.set_option('display.max_columns', None)

# %%
# 한글폰트 사용
import os

if os.name == 'posix':

    plt.rc("font", family="AppleGothic")
else :

    plt.rc("font", family="Malgun Gothic")

# %%
df = pd.read_csv('covid_data.csv', index_col = 0)
df.head(3)
# Out:
#        연번      환자         확진일   거주지 여행력       접촉력 퇴원현황
# 0  171606  489483  2021-12-07   송파구   -  감염경로 조사중  NaN
# 1  171605  486883  2021-12-07  서대문구   -  감염경로 조사중  NaN
# 2  171604  489471  2021-12-07   서초구   -  감염경로 조사중  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171200 entries, 0 to 171199
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   연번      171200 non-null  int64
#  1   환자      171200 non-null  int64
#  2   확진일     171200 non-null  object
#  3   거주지     171200 non-null  object
#  4   여행력     171200 non-null  object
#  5   접촉력     171200 non-null  object
#  6   퇴원현황    134761 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 10.4+ MB

# %%
df["확진일"] = pd.to_datetime(df["확진일"])
df["확진일"] = pd.to_datetime(df["확진일"])
df["년"] = df["확진일"].dt.year
df["월"] = df["확진일"].dt.month
df["일"] = df["확진일"].dt.day
df["주"] = df["확진일"].dt.week

df[["확진일", "년", "월", "일", "주"]]
# Out:
#               확진일     년   월  일   주
# 0      2021-12-07  2021  12  7  49
# 1      2021-12-07  2021  12  7  49
# 2      2021-12-07  2021  12  7  49
# 3      2021-12-07  2021  12  7  49
# 4      2021-12-07  2021  12  7  49
# ...           ...   ...  .. ..  ..
# 171195 2020-03-04  2020   3  4  10
# 171196 2020-03-04  2020   3  4  10
# 171197 2020-03-04  2020   3  4  10
# 171198 2020-03-04  2020   3  4  10
# 171199 2020-03-04  2020   3  4  10
#
# [171200 rows x 5 columns]

# %%
#20년 말에 확진자 급증은 추석연휴 간 이동, 수도권을 중심으로 집단감역 
#2021-7월 코로나 확진자수 증가 원인은 실내체육시설, 어린이집, 직장 등 각종 생활시설에서 신규 집단감염
# 2021-10월 중순부터 확진수가 급증한 양상을 볼 수 있습니다. 이는 거리두기 단계를 완하하고 단계적 일상회복이 시행된 시기랑 동일합니다.


fig , ax = plt.subplots(figsize = (20,10))

ax.plot(df["확진일"].value_counts().sort_index())
ax.set_title("기간에 따른 확진자 수 변화")
plt.show()

# %% [markdown]
# ### 확진자가 급증했던 기간 접촉력 확인

# %%
df_7_9 = df[(df["확진일"] >= '2020-7-1') & (df["확진일"] <= '2020-9-30')]["접촉력"].value_counts().sort_values(ascending =False).head(20)

# %%
# 사랑제일교회 여파 
fig , ax = plt.subplots(figsize = (10,8))

df_7_9.plot.bar()
ax.set_title("2020-7-1 ~ 2020-9-30  확진자수 별 접촉력")
plt.show()

# %%
df_11_1 = df[(df["확진일"] >= '2020-11-1') & (df["확진일"] <= '2021-1-30')]["접촉력"].value_counts().sort_values(ascending =False).head(20)

# %%
# 동부구치소 여파 
fig , ax = plt.subplots(figsize = (10,8))

df_11_1.plot.bar()
ax.set_title("2020-11-1 ~ 2020-1-30  확진자수 별 접촉력")
plt.show()

# %%
df_11_12 = df[(df["확진일"] >= '2021-11-1') & (df["확진일"] <= '2021-12-7')]["접촉력"].value_counts().sort_values(ascending =False).head(20)

# %%
# 21년 말 부터 집단감염이 다분했던 20년도와 상이하게 산발적으로 지역감염이 많이 일어나고 있다는 것을 볼 수 있다.
fig , ax = plt.subplots(figsize = (10,8))

df_11_12.plot.bar()
ax.set_title("2021-11-1 ~ 2021-12-7  확진자수 별 접촉력")
plt.show()

# %% [markdown]
# ### 접촉력 별 확진자 분석

# %%
# 전체 기준 
top = df["접촉력"].value_counts().sort_values().tail(10)
top.plot.bar(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
top_group = df[df["접촉력"].isin(top.tail(15).index)]
top_group
# Out:
#             연번      환자        확진일   거주지 여행력         접촉력 퇴원현황     년   월  일   주
# 0       171606  489483 2021-12-07   송파구   -    감염경로 조사중  NaN  2021  12  7  49
# 1       171605  486883 2021-12-07  서대문구   -    감염경로 조사중  NaN  2021  12  7  49
# 2       171604  489471 2021-12-07   서초구   -    감염경로 조사중  NaN  2021  12  7  49
# 3       171603  489470 2021-12-07   서초구   -    감염경로 조사중  NaN  2021  12  7  49
# 4       171602  489469 2021-12-07   종로구   -    감염경로 조사중  NaN  2021  12  7  49
# ...        ...     ...        ...   ...  ..         ...  ...   ...  .. ..  ..
# 171195     105    6070 2020-03-04   강북구   -    감염경로 조사중   퇴원  2020   3  4  10
# 171196     104    6832 2020-03-04   강북구   -   기타 확진자 접촉   퇴원  2020   3  4  10
# 171197     103    5666 2020-03-04   용산구   -   기타 확진자 접촉   퇴원  2020   3  4  10
# 171198     102    5695 2020-03-04  동대문구  유럽        해외유입   퇴원  2020   3  4  10
# 171199     101    5661 2020-03-04   중랑구   -  타시도 확진자 접촉   퇴원  2020   3  4  10
#
# [144062 rows x 11 columns]

# %%
# 2020년 기준 
top_group_2020 = top_group[top_group["년"]==2020].groupby(["접촉력", "월"])["연번"].count().unstack().fillna(0).astype(int)
top_group_2020.style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
# #T_370ca_row0_col0{
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }#T_370ca_row0_col1{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_370ca_row0_col2{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_370ca_row0_col3,#T_370ca_row0_col4,#T_370ca_row0_col7,#T_370ca_row1_col6,#T_370ca_row1_col8,#T_370ca_row1_col9,#T_370ca_row4_col5,#T_370ca_row6_col0,#T_370ca_row6_col1,#T_370ca_row6_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_370ca_row0_col5{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_370ca_row0_col6{
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }#T_370ca_row0_col8{
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }#T_370ca_row0_col9{
#             background-color:  #3484bf;
#             color:  #000000;
#         }#T_370ca_row1_col0{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_370ca_row1_col1,#T_370ca_row5_col2,#T_370ca_row6_col5{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_370ca_row1_col2,#T_370ca_row2_col0,#T_370ca_row2_col1,#T_370ca_row2_col2,#T_370ca_row2_col3,#T_370ca_row2_col4,#T_370ca_row2_col5,#T_370ca_row2_col6,#T_370ca_row2_col7,#T_370ca_row3_col0,#T_370ca_row3_col1,#T_370ca_row3_col2,#T_370ca_row3_col3,#T_370ca_row3_col4,#T_370ca_row3_col5,#T_370ca_row3_col6,#T_370ca_row3_col7,#T_370ca_row3_col8,#T_370ca_row3_col9,#T_370ca_row4_col0,#T_370ca_row4_col1,#T_370ca_row4_col2,#T_370ca_row4_col3,#T_370ca_row4_col4,#T_370ca_row4_col7,#T_370ca_row4_col8,#T_370ca_row4_col9{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_370ca_row1_col3{
#             background-color:  #cde0f1;
#             color:  #000000;
#         }#T_370ca_row1_col4{
#             background-color:  #3585bf;
#             color:  #000000;
#         }#T_370ca_row1_col5{
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }#T_370ca_row1_col7{
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }#T_370ca_row2_col8{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_370ca_row2_col9,#T_370ca_row5_col6{
#             background-color:  #caddf0;
#             color:  #000000;
#         }#T_370ca_row4_col6{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_370ca_row5_col0{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_370ca_row5_col1{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_370ca_row5_col3{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_370ca_row5_col4{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_370ca_row5_col5{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }#T_370ca_row5_col7{
#             background-color:  #bed8ec;
#             color:  #000000;
#         }#T_370ca_row5_col8{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_370ca_row5_col9{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_370ca_row6_col3{
#             background-color:  #a6cee4;
#             color:  #000000;
#         }#T_370ca_row6_col4{
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }#T_370ca_row6_col6{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_370ca_row6_col7{
#             background-color:  #a1cbe2;
#             color:  #000000;
#         }#T_370ca_row6_col8{
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }#T_370ca_row6_col9{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }</style><table id="T_370ca_" ><thead>    <tr>        <th class="index_name level0" >월</th>        <th class="col_heading level0 col0" >3</th>        <th class="col_heading level0 col1" >4</th>        <th class="col_heading level0 col2" >5</th>        <th class="col_heading level0 col3" >6</th>        <th class="col_heading level0 col4" >7</th>        <th class="col_heading level0 col5" >8</th>        <th class="col_heading level0 col6" >9</th>        <th class="col_heading level0 col7" >10</th>        <th class="col_heading level0 col8" >11</th>        <th class="col_heading level0 col9" >12</th>    </tr>    <tr>        <th class="index_name level0" >접촉력</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_370ca_level0_row0" class="row_heading level0 row0" >감염경로 조사중</th>
#                         <td id="T_370ca_row0_col0" class="data row0 col0" >38</td>
#                         <td id="T_370ca_row0_col1" class="data row0 col1" >16</td>
#                         <td id="T_370ca_row0_col2" class="data row0 col2" >5</td>
#                         <td id="T_370ca_row0_col3" class="data row0 col3" >66</td>
#                         <td id="T_370ca_row0_col4" class="data row0 col4" >49</td>
#                         <td id="T_370ca_row0_col5" class="data row0 col5" >440</td>
#                         <td id="T_370ca_row0_col6" class="data row0 col6" >286</td>
#                         <td id="T_370ca_row0_col7" class="data row0 col7" >120</td>
#                         <td id="T_370ca_row0_col8" class="data row0 col8" >474</td>
#                         <td id="T_370ca_row0_col9" class="data row0 col9" >2729</td>
#             </tr>
#             <tr>
#                         <th id="T_370ca_level0_row1" class="row_heading level0 row1" >기타 확진자 접촉</th>
#                         <td id="T_370ca_row1_col0" class="data row1 col0" >20</td>
#                         <td id="T_370ca_row1_col1" class="data row1 col1" >9</td>
#                         <td id="T_370ca_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_370ca_row1_col3" class="data row1 col3" >14</td>
#                         <td id="T_370ca_row1_col4" class="data row1 col4" >33</td>
#                         <td id="T_370ca_row1_col5" class="data row1 col5" >439</td>
#                         <td id="T_370ca_row1_col6" class="data row1 col6" >304</td>
#                         <td id="T_370ca_row1_col7" class="data row1 col7" >116</td>
#                         <td id="T_370ca_row1_col8" class="data row1 col8" >631</td>
#                         <td id="T_370ca_row1_col9" class="data row1 col9" >4023</td>
#             </tr>
#             <tr>
#                         <th id="T_370ca_level0_row2" class="row_heading level0 row2" >동부구치소 관련</th>
#                         <td id="T_370ca_row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_370ca_row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_370ca_row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_370ca_row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_370ca_row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_370ca_row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_370ca_row2_col6" class="data row2 col6" >0</td>
#                         <td id="T_370ca_row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_370ca_row2_col8" class="data row2 col8" >3</td>
#                         <td id="T_370ca_row2_col9" class="data row2 col9" >930</td>
#             </tr>
#             <tr>
#                         <th id="T_370ca_level0_row3" class="row_heading level0 row3" >병원 및 요양시설</th>
#                         <td id="T_370ca_row3_col0" class="data row3 col0" >0</td>

# %%
fig = plt.figure(figsize = (10,8))

sns.heatmap(top_group_2020,cmap =  "Blues")
plt.show()

# %%
# 2021년 기준 
top_group_2021 = top_group[top_group["년"]==2021].groupby(["접촉력", "월"])["연번"].count().unstack().fillna(0).astype(int)
top_group_2021.style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
# #T_a58f1_row0_col0{
#             background-color:  #dd2a25;
#             color:  #f1f1f1;
#         }#T_a58f1_row0_col1{
#             background-color:  #ea362a;
#             color:  #f1f1f1;
#         }#T_a58f1_row0_col2{
#             background-color:  #c7171c;
#             color:  #f1f1f1;
#         }#T_a58f1_row0_col3{
#             background-color:  #ce1a1e;
#             color:  #f1f1f1;
#         }#T_a58f1_row0_col4{
#             background-color:  #cb181d;
#             color:  #f1f1f1;
#         }#T_a58f1_row0_col5,#T_a58f1_row0_col8,#T_a58f1_row0_col9,#T_a58f1_row0_col11,#T_a58f1_row1_col0,#T_a58f1_row1_col1,#T_a58f1_row1_col2,#T_a58f1_row1_col3,#T_a58f1_row1_col4,#T_a58f1_row1_col5,#T_a58f1_row1_col6,#T_a58f1_row1_col7,#T_a58f1_row1_col8,#T_a58f1_row1_col10{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_a58f1_row0_col6{
#             background-color:  #ad1117;
#             color:  #f1f1f1;
#         }#T_a58f1_row0_col7{
#             background-color:  #b21218;
#             color:  #f1f1f1;
#         }#T_a58f1_row0_col10{
#             background-color:  #a50f15;
#             color:  #f1f1f1;
#         }#T_a58f1_row1_col9{
#             background-color:  #7e0610;
#             color:  #f1f1f1;
#         }#T_a58f1_row1_col11{
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }#T_a58f1_row2_col0{
#             background-color:  #fee1d3;
#             color:  #000000;
#         }#T_a58f1_row2_col1,#T_a58f1_row2_col2,#T_a58f1_row2_col3,#T_a58f1_row2_col4,#T_a58f1_row2_col5,#T_a58f1_row2_col6,#T_a58f1_row2_col7,#T_a58f1_row2_col8,#T_a58f1_row2_col9,#T_a58f1_row2_col10,#T_a58f1_row2_col11,#T_a58f1_row3_col0,#T_a58f1_row3_col1,#T_a58f1_row3_col2,#T_a58f1_row3_col3,#T_a58f1_row3_col4,#T_a58f1_row3_col5,#T_a58f1_row3_col6,#T_a58f1_row3_col7,#T_a58f1_row3_col8,#T_a58f1_row3_col9,#T_a58f1_row5_col0,#T_a58f1_row5_col1,#T_a58f1_row5_col2,#T_a58f1_row5_col3,#T_a58f1_row5_col4,#T_a58f1_row5_col5,#T_a58f1_row5_col6,#T_a58f1_row5_col7,#T_a58f1_row5_col8,#T_a58f1_row5_col9,#T_a58f1_row6_col0,#T_a58f1_row6_col1,#T_a58f1_row6_col2,#T_a58f1_row6_col3,#T_a58f1_row6_col4,#T_a58f1_row6_col5,#T_a58f1_row6_col6,#T_a58f1_row6_col7,#T_a58f1_row6_col10,#T_a58f1_row6_col11{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_a58f1_row3_col10,#T_a58f1_row4_col3,#T_a58f1_row4_col5,#T_a58f1_row8_col4{
#             background-color:  #fff0e8;
#             color:  #000000;
#         }#T_a58f1_row3_col11,#T_a58f1_row6_col9,#T_a58f1_row7_col11,#T_a58f1_row8_col10{
#             background-color:  #fff4ee;
#             color:  #000000;
#         }#T_a58f1_row4_col0,#T_a58f1_row4_col6,#T_a58f1_row4_col9,#T_a58f1_row8_col7{
#             background-color:  #fff0e9;
#             color:  #000000;
#         }#T_a58f1_row4_col1{
#             background-color:  #ffece3;
#             color:  #000000;
#         }#T_a58f1_row4_col2,#T_a58f1_row4_col4,#T_a58f1_row8_col2{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_a58f1_row4_col7,#T_a58f1_row4_col8{
#             background-color:  #fff2eb;
#             color:  #000000;
#         }#T_a58f1_row4_col10,#T_a58f1_row8_col6{
#             background-color:  #fff1ea;
#             color:  #000000;
#         }#T_a58f1_row4_col11,#T_a58f1_row5_col10{
#             background-color:  #fff2ec;
#             color:  #000000;
#         }#T_a58f1_row5_col11,#T_a58f1_row7_col9,#T_a58f1_row7_col10,#T_a58f1_row8_col8,#T_a58f1_row8_col9{
#             background-color:  #fff3ed;
#             color:  #000000;
#         }#T_a58f1_row6_col8,#T_a58f1_row8_col0{
#             background-color:  #fee8de;
#             color:  #000000;
#         }#T_a58f1_row7_col0{
#             background-color:  #fee3d7;
#             color:  #000000;
#         }#T_a58f1_row7_col1{
#             background-color:  #fee5d9;
#             color:  #000000;
#         }#T_a58f1_row7_col2{
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }#T_a58f1_row7_col3{
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }#T_a58f1_row7_col4,#T_a58f1_row7_col5{
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }#T_a58f1_row7_col6{
#             background-color:  #fee5d8;
#             color:  #000000;
#         }#T_a58f1_row7_col7{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_a58f1_row7_col8{
#             background-color:  #feeae0;
#             color:  #000000;
#         }#T_a58f1_row8_col1{
#             background-color:  #fee7db;
#             color:  #000000;
#         }#T_a58f1_row8_col3{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_a58f1_row8_col5{
#             background-color:  #ffeee6;
#             color:  #000000;
#         }#T_a58f1_row8_col11{
#             background-color:  #fff4ef;
#             color:  #000000;
#         }</style><table id="T_a58f1_" ><thead>    <tr>        <th class="index_name level0" >월</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >4</th>        <th class="col_heading level0 col4" >5</th>        <th class="col_heading level0 col5" >6</th>        <th class="col_heading level0 col6" >7</th>        <th class="col_heading level0 col7" >8</th>        <th class="col_heading level0 col8" >9</th>        <th class="col_heading level0 col9" >10</th>        <th class="col_heading level0 col10" >11</th>        <th class="col_heading level0 col11" >12</th>    </tr>    <tr>        <th class="index_name level0" >접촉력</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a58f1_level0_row0" class="row_heading level0 row0" >감염경로 조사중</th>
#                         <td id="T_a58f1_row0_col0" class="data row0 col0" >1348</td>
#                         <td id="T_a58f1_row0_col1" class="data row0 col1" >964</td>
#                         <td id="T_a58f1_row0_col2" class="data row0 col2" >1012</td>
#                         <td id="T_a58f1_row0_col3" class="data row0 col3" >1517</td>
#                         <td id="T_a58f1_row0_col4" class="data row0 col4" >1675</td>
#                         <td id="T_a58f1_row0_col5" class="data row0 col5" >2270</td>
#                         <td id="T_a58f1_row0_col6" class="data row0 col6" >5231</td>
#                         <td id="T_a58f1_row0_col7" class="data row0 col7" >5601</td>
#                         <td id="T_a58f1_row0_col8" class="data row0 col8" >8871</td>
#                         <td id="T_a58f1_row0_col9" class="data row0 col9" >8124</td>
#                         <td id="T_a58f1_row0_col10" class="data row0 col10" >14278</td>
#                         <td id="T_a58f1_row0_col11" class="data row0 col11" >7576</td>
#             </tr>
#             <tr>
#                         <th id="T_a58f1_level0_row1" class="row_heading level0 row1" >기타 확진자 접촉</th>
#                         <td id="T_a58f1_row1_col0" class="data row1 col0" >1961</td>
#                         <td id="T_a58f1_row1_col1" class="data row1 col1" >1497</td>
#                         <td id="T_a58f1_row1_col2" class="data row1 col2" >1324</td>
#                         <td id="T_a58f1_row1_col3" class="data row1 col3" >2047</td>
#                         <td id="T_a58f1_row1_col4" class="data row1 col4" >2244</td>
#                         <td id="T_a58f1_row1_col5" class="data row1 col5" >2264</td>
#                         <td id="T_a58f1_row1_col6" class="data row1 col6" >6172</td>
#                         <td id="T_a58f1_row1_col7" class="data row1 col7" >6734</td

# %%
fig = plt.figure(figsize = (10,8))

sns.heatmap(top_group_2021,cmap =  "Reds")
plt.show()

# %% [markdown]
# ### 퇴원자 사망자 비교

# %%
df["퇴원"] = df["퇴원현황"].str.contains("퇴원", na=False)
df["사망"] = df["퇴원현황"].str.contains("사망", na=False)

# %%
np.round(df["퇴원"].value_counts(normalize=True),2)
# Out:
# True     0.78
# False    0.22
# Name: 퇴원, dtype: float64

# %%
np.round(df["사망"].value_counts(normalize=True),2)
# Out:
# False    0.99
# True     0.01
# Name: 사망, dtype: float64

# %%
df_dead = df[df["퇴원현황"] == "사망"]
df_alive = df[df["퇴원현황"] == "퇴원"]

# %%
df_dead.head(3)
# Out:
#           연번      환자        확진일  거주지 여행력       접촉력 퇴원현황     년   월  일   주  \
# 3005  168701  481957 2021-12-06  도봉구   -  감염경로 조사중   사망  2021  12  6  49
# 3022  168684  481827 2021-12-06  구로구   -  감염경로 조사중   사망  2021  12  6  49
# 3114  168592  480720 2021-12-06  양천구   -  감염경로 조사중   사망  2021  12  6  49
#
#          퇴원    사망
# 3005  False  True
# 3022  False  True
# 3114  False  True

# %%
# 2020월별 사망자수 
df_d_2020 = df_dead[df_dead["년"]==2020].groupby(["퇴원현황", "월"])["연번"].count().unstack().fillna(0).astype(int)
df_d_2020.style.background_gradient(cmap="Reds", vmin =0 ,vmax = 400)
# Out:
# <style  type="text/css" >
# #T_b780f_row0_col0{
#             background-color:  #fff4ef;
#             color:  #000000;
#         }#T_b780f_row0_col1,#T_b780f_row0_col5{
#             background-color:  #fff2ec;
#             color:  #000000;
#         }#T_b780f_row0_col2{
#             background-color:  #fff4ee;
#             color:  #000000;
#         }#T_b780f_row0_col3{
#             background-color:  #fee5d9;
#             color:  #000000;
#         }#T_b780f_row0_col4{
#             background-color:  #ffebe2;
#             color:  #000000;
#         }#T_b780f_row0_col6{
#             background-color:  #fee3d6;
#             color:  #000000;
#         }#T_b780f_row0_col7{
#             background-color:  #fb7b5b;
#             color:  #000000;
#         }</style><table id="T_b780f_" ><thead>    <tr>        <th class="index_name level0" >월</th>        <th class="col_heading level0 col0" >3</th>        <th class="col_heading level0 col1" >6</th>        <th class="col_heading level0 col2" >7</th>        <th class="col_heading level0 col3" >8</th>        <th class="col_heading level0 col4" >9</th>        <th class="col_heading level0 col5" >10</th>        <th class="col_heading level0 col6" >11</th>        <th class="col_heading level0 col7" >12</th>    </tr>    <tr>        <th class="index_name level0" >퇴원현황</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b780f_level0_row0" class="row_heading level0 row0" >사망</th>
#                         <td id="T_b780f_row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_b780f_row0_col1" class="data row0 col1" >7</td>
#                         <td id="T_b780f_row0_col2" class="data row0 col2" >4</td>
#                         <td id="T_b780f_row0_col3" class="data row0 col3" >39</td>
#                         <td id="T_b780f_row0_col4" class="data row0 col4" >24</td>
#                         <td id="T_b780f_row0_col5" class="data row0 col5" >7</td>
#                         <td id="T_b780f_row0_col6" class="data row0 col6" >44</td>
#                         <td id="T_b780f_row0_col7" class="data row0 col7" >179</td>
#             </tr>
#     </tbody></table>

# %%
# 2020일별 사망자수 (계절성)
df_d_2020 = df_dead[df_dead["년"]==2020].groupby(["퇴원현황", "월","일"])["연번"].count().unstack().fillna(0).astype(int)
df_d_2020.style.background_gradient(cmap="Reds", vmin =0 ,vmax = 20)
# Out:
# <style  type="text/css" >
# #T_69fed_row0_col0,#T_69fed_row0_col1,#T_69fed_row0_col2,#T_69fed_row0_col3,#T_69fed_row0_col4,#T_69fed_row0_col5,#T_69fed_row0_col7,#T_69fed_row0_col8,#T_69fed_row0_col9,#T_69fed_row0_col10,#T_69fed_row0_col11,#T_69fed_row0_col12,#T_69fed_row0_col13,#T_69fed_row0_col14,#T_69fed_row0_col15,#T_69fed_row0_col16,#T_69fed_row0_col17,#T_69fed_row0_col19,#T_69fed_row0_col20,#T_69fed_row0_col21,#T_69fed_row0_col22,#T_69fed_row0_col23,#T_69fed_row0_col24,#T_69fed_row0_col25,#T_69fed_row0_col26,#T_69fed_row0_col27,#T_69fed_row0_col28,#T_69fed_
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }#T_69fed_row7_col18,#T_69fed_row7_col22,#T_69fed_row7_col24{
#             background-color:  #fb7a5a;
#             color:  #000000;
#         }#T_69fed_row7_col27{
#             background-color:  #d92523;
#             color:  #f1f1f1;
#         }#T_69fed_row7_col28{
#             background-color:  #f6583e;
#             color:  #000000;
#         }</style><table id="T_69fed_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >일</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >4</th>        <th class="col_heading level0 col4" >5</th>        <th class="col_heading level0 col5" >6</th>        <th class="col_heading level0 col6" >7</th>        <th class="col_heading level0 col7" >8</th>        <th class="col_heading level0 col8" >9</th>        <th class="col_heading level0 col9" >10</th>        <th class="col_heading level0 col10" >11</th>        <th class="col_heading level0 col11" >12</th>        <th class="col_heading level0 col12" >13</th>        <th class="col_heading level0 col13" >14</th>        <th class="col_heading level0 col14" >15</th>        <th class="col_heading level0 col15" >16</th>        <th class="col_heading level0 col16" >17</th>        <th class="col_heading level0 col17" >18</th>        <th class="col_heading level0 col18" >19</th>        <th class="col_heading level0 col19" >20</th>        <th class="col_heading level0 col20" >21</th>        <th class="col_heading level0 col21" >22</th>        <th class="col_heading level0 col22" >23</th>        <th class="col_heading level0 col23" >24</th>        <th class="col_heading level0 col24" >25</th>        <th class="col_heading level0 col25" >26</th>        <th class="col_heading level0 col26" >27</th>        <th class="col_heading level0 col27" >28</th>        <th class="col_heading level0 col28" >29</th>        <th class="col_heading level0 col29" >30</th>        <th class="col_heading level0 col30" >31</th>    </tr>    <tr>        <th class="index_name level0" >퇴원현황</th>        <th class="index_name level1" >월</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>

# %%
# 2020월별 퇴원자수
df_alive_2021 = df_alive[df_alive["년"]==2020].groupby(["퇴원현황", "월"])["연번"].count().unstack().fillna(0).astype(int)
df_alive_2021.style.background_gradient(cmap="Greens",vmin =4000 ,vmax = 20000)
# Out:
# <style  type="text/css" >
# #T_d1dcd_row0_col0,#T_d1dcd_row0_col1,#T_d1dcd_row0_col2,#T_d1dcd_row0_col3,#T_d1dcd_row0_col4,#T_d1dcd_row0_col5,#T_d1dcd_row0_col6,#T_d1dcd_row0_col7,#T_d1dcd_row0_col8{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_d1dcd_row0_col9{
#             background-color:  #9bd696;
#             color:  #000000;
#         }</style><table id="T_d1dcd_" ><thead>    <tr>        <th class="index_name level0" >월</th>        <th class="col_heading level0 col0" >3</th>        <th class="col_heading level0 col1" >4</th>        <th class="col_heading level0 col2" >5</th>        <th class="col_heading level0 col3" >6</th>        <th class="col_heading level0 col4" >7</th>        <th class="col_heading level0 col5" >8</th>        <th class="col_heading level0 col6" >9</th>        <th class="col_heading level0 col7" >10</th>        <th class="col_heading level0 col8" >11</th>        <th class="col_heading level0 col9" >12</th>    </tr>    <tr>        <th class="index_name level0" >퇴원현황</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d1dcd_level0_row0" class="row_heading level0 row0" >퇴원</th>
#                         <td id="T_d1dcd_row0_col0" class="data row0 col0" >375</td>
#                         <td id="T_d1dcd_row0_col1" class="data row0 col1" >156</td>
#                         <td id="T_d1dcd_row0_col2" class="data row0 col2" >229</td>
#                         <td id="T_d1dcd_row0_col3" class="data row0 col3" >452</td>
#                         <td id="T_d1dcd_row0_col4" class="data row0 col4" >277</td>
#                         <td id="T_d1dcd_row0_col5" class="data row0 col5" >2376</td>
#                         <td id="T_d1dcd_row0_col6" class="data row0 col6" >1282</td>
#                         <td id="T_d1dcd_row0_col7" class="data row0 col7" >726</td>
#                         <td id="T_d1dcd_row0_col8" class="data row0 col8" >2860</td>
#                         <td id="T_d1dcd_row0_col9" class="data row0 col9" >10253</td>
#             </tr>
#     </tbody></table>

# %%
# 2021월별 사망자수 
df_d_2021 = df_dead[df_dead["년"]==2021].groupby(["퇴원현황", "월"])["연번"].count().unstack().fillna(0).astype(int)
df_d_2021.style.background_gradient(cmap="Reds", vmin =0 ,vmax = 400)
# Out:
# <style  type="text/css" >
# #T_71b92_row0_col0{
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }#T_71b92_row0_col1{
#             background-color:  #fee1d3;
#             color:  #000000;
#         }#T_71b92_row0_col2{
#             background-color:  #feeae1;
#             color:  #000000;
#         }#T_71b92_row0_col3{
#             background-color:  #fee9df;
#             color:  #000000;
#         }#T_71b92_row0_col4{
#             background-color:  #fee5d9;
#             color:  #000000;
#         }#T_71b92_row0_col5{
#             background-color:  #ffece3;
#             color:  #000000;
#         }#T_71b92_row0_col6,#T_71b92_row0_col11{
#             background-color:  #fee7dc;
#             color:  #000000;
#         }#T_71b92_row0_col7{
#             background-color:  #fee1d4;
#             color:  #000000;
#         }#T_71b92_row0_col8{
#             background-color:  #fcbca2;
#             color:  #000000;
#         }#T_71b92_row0_col9{
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }#T_71b92_row0_col10{
#             background-color:  #a91016;
#             color:  #f1f1f1;
#         }</style><table id="T_71b92_" ><thead>    <tr>        <th class="index_name level0" >월</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >4</th>        <th class="col_heading level0 col4" >5</th>        <th class="col_heading level0 col5" >6</th>        <th class="col_heading level0 col6" >7</th>        <th class="col_heading level0 col7" >8</th>        <th class="col_heading level0 col8" >9</th>        <th class="col_heading level0 col9" >10</th>        <th class="col_heading level0 col10" >11</th>        <th class="col_heading level0 col11" >12</th>    </tr>    <tr>        <th class="index_name level0" >퇴원현황</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_71b92_level0_row0" class="row_heading level0 row0" >사망</th>
#                         <td id="T_71b92_row0_col0" class="data row0 col0" >65</td>
#                         <td id="T_71b92_row0_col1" class="data row0 col1" >49</td>
#                         <td id="T_71b92_row0_col2" class="data row0 col2" >25</td>
#                         <td id="T_71b92_row0_col3" class="data row0 col3" >29</td>
#                         <td id="T_71b92_row0_col4" class="data row0 col4" >38</td>
#                         <td id="T_71b92_row0_col5" class="data row0 col5" >23</td>
#                         <td id="T_71b92_row0_col6" class="data row0 col6" >34</td>
#                         <td id="T_71b92_row0_col7" class="data row0 col7" >48</td>
#                         <td id="T_71b92_row0_col8" class="data row0 col8" >99</td>
#                         <td id="T_71b92_row0_col9" class="data row0 col9" >156</td>
#                         <td id="T_71b92_row0_col10" class="data row0 col10" >344</td>
#                         <td id="T_71b92_row0_col11" class="data row0 col11" >33</td>
#             </tr>
#     </tbody></table>

# %%
# 2021일별 사망자수 (계절성, 중환자수가 늘어나서 인가? )
df_d_2021 = df_dead[df_dead["년"]==2021].groupby(["퇴원현황", "월","일"])["연번"].count().unstack().fillna(0).astype(int)
df_d_2021.style.background_gradient(cmap="Reds", vmin =0 ,vmax = 20)
# Out:
# <style  type="text/css" >
# #T_2f2dd_row0_col0,#T_2f2dd_row0_col9,#T_2f2dd_row1_col2,#T_2f2dd_row4_col21,#T_2f2dd_row6_col23,#T_2f2dd_row8_col4,#T_2f2dd_row8_col17,#T_2f2dd_row8_col20,#T_2f2dd_row8_col23,#T_2f2dd_row9_col10,#T_2f2dd_row9_col26,#T_2f2dd_row10_col7,#T_2f2dd_row10_col29,#T_2f2dd_row11_col1{
#             background-color:  #fcbba1;
#             color:  #000000;
#         }#T_2f2dd_row0_col1,#T_2f2dd_row9_col13,#T_2f2dd_row9_col18,#T_2f2dd_row9_col20,#T_2f2dd_row10_col1,#T_2f2dd_row10_col27{
#             background-color:  #fc9b7c;
#             color:  #000000;
#         
#T_2f2dd_row5_col29,#T_2f2dd_row6_col4,#T_2f2dd_row6_col6,#T_2f2dd_row6_col8,#T_2f2dd_row6_col12,#T_2f2dd_row6_col13,#T_2f2dd_row6_col16,#T_2f2dd_row6_col17,#T_2f2dd_row6_col18,#T_2f2dd_row6_col20,#T_2f2dd_row6_col21,#T_2f2dd_row6_col28,#T_2f2dd_row7_col2,#T_2f2dd_row7_col3,#T_2f2dd_row7_col4,#T_2f2dd_row7_col7,#T_2f2dd_row7_col10,#T_2f2dd_row7_col15,#T_2f2dd_row7_col20,#T_2f2dd_row7_col21,#T_2f2dd_row7_col22,#T_2f2dd_row7_col30,#T_2f2dd_row8_col1,#T_2f2dd_row8_col5,#T_2f2dd_row8_col6,#T_2f2dd_row8_col9,#T_2f2dd_row8_col11,#T_2f2dd_row8_col14,#T_2f2dd_row8_col16,#T_2f2dd_row9_col2,#T_2f2dd_row9_col8,#T_2f2dd_row9_col22{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_2f2dd_row1_col12,#T_2f2dd_row8_col13,#T_2f2dd_row8_col28,#T_2f2dd_row8_col29,#T_2f2dd_row9_col0,#T_2f2dd_row9_col6,#T_2f2dd_row9_col24,#T_2f2dd_row9_col27,#T_2f2dd_row9_col29,#T_2f2dd_row10_col0,#T_2f2dd_row10_col4,#T_2f2dd_row10_col18,#T_2f2dd_row10_col23,#T_2f2dd_row10_col28{
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }#T_2f2dd_row8_col26,#T_2f2dd_row9_col1,#T_2f2dd_row9_col21,#T_2f2dd_row10_col3,#T_2f2dd_row10_col14{
#             background-color:  #fb694a;
#             color:  #000000;
#         }#T_2f2dd_row10_col6,#T_2f2dd_row10_col24,#T_2f2dd_row10_col25,#T_2f2dd_row11_col0{
#             background-color:  #f6583e;
#             color:  #000000;
#         }#T_2f2dd_row10_

# %%
#2021월별 퇴원자수 
df_alive_2021 = df_alive[df_alive["년"]==2021].groupby(["퇴원현황", "월"])["연번"].count().unstack().fillna(0).astype(int)
df_alive_2021.style.background_gradient(cmap="Greens",vmin =4000 ,vmax = 20000)
# Out:
# <style  type="text/css" >
# #T_75628_row0_col0{
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }#T_75628_row0_col1,#T_75628_row0_col2,#T_75628_row0_col11{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_75628_row0_col3{
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }#T_75628_row0_col4{
#             background-color:  #e5f5e1;
#             color:  #000000;
#         }#T_75628_row0_col5{
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }#T_75628_row0_col6{
#             background-color:  #3aa357;
#             color:  #000000;
#         }#T_75628_row0_col7{
#             background-color:  #369f54;
#             color:  #000000;
#         }#T_75628_row0_col8{
#             background-color:  #0a7633;
#             color:  #f1f1f1;
#         }#T_75628_row0_col9{
#             background-color:  #2c944c;
#             color:  #000000;
#         }#T_75628_row0_col10{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_75628_" ><thead>    <tr>        <th class="index_name level0" >월</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >4</th>        <th class="col_heading level0 col4" >5</th>        <th class="col_heading level0 col5" >6</th>        <th class="col_heading level0 col6" >7</th>        <th class="col_heading level0 col7" >8</th>        <th class="col_heading level0 col8" >9</th>        <th class="col_heading level0 col9" >10</th>        <th class="col_heading level0 col10" >11</th>        <th class="col_heading level0 col11" >12</th>    </tr>    <tr>        <th class="index_name level0" >퇴원현황</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75628_level0_row0" class="row_heading level0 row0" >퇴원</th>
#                         <td id="T_75628_row0_col0" class="data row0 col0" >4813</td>
#                         <td id="T_75628_row0_col1" class="data row0 col1" >4011</td>
#                         <td id="T_75628_row0_col2" class="data row0 col2" >3872</td>
#                         <td id="T_75628_row0_col3" class="data row0 col3" >5774</td>
#                         <td id="T_75628_row0_col4" class="data row0 col4" >5992</td>
#                         <td id="T_75628_row0_col5" class="data row0 col5" >6235</td>
#                         <td id="T_75628_row0_col6" class="data row0 col6" >14445</td>
#                         <td id="T_75628_row0_col7" class="data row0 col7" >14702</td>
#                         <td id="T_75628_row0_col8" class="data row0 col8" >17403</td>
#                         <td id="T_75628_row0_col9" class="data row0 col9" >15401</td>
#                         <td id="T_75628_row0_col10" class="data row0 col10" >21753</td>
#                         <td id="T_75628_row0_col11" class="data row0 col11" >124</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 여행력 별 확진자 분석

# %%
df["해외"] = df["여행력"] 
df["해외"] = df["해외"].replace('-', np.nan) # - 를 Nan으로 교체

# df_oversea: 해외 칼럼 데이터를 가진 경우만 필터링
df_oversea = df[df["해외"].notnull()].copy()
df_oversea.drop(df_oversea[df_oversea["해외"]=='28238'].index, inplace=True) # 환자 번호가 잘못 들어간 row 데이터 삭제
df_oversea.drop(df_oversea[df_oversea["해외"]=='21263'].index, inplace=True) # 환자 번호가 잘못 들어간 row 데이터 삭제

# %%
europe = "체코,헝가리,오스트리아,이탈리아,프랑스,모로코,독일,스페인,영국,폴란드,터키,아일랜드"
europe = europe.replace(",", "|")
south_america = "브라질,아르헨티아,칠레,볼리비아,멕시코,페루"
south_america = south_america.replace(",", "|")

df_oversea.loc[df_oversea["해외"].str.contains(europe), "해외"] = '유럽'
df_oversea.loc[df_oversea["해외"].str.contains(south_america), "해외"] = '남미'
df_oversea.loc[df_oversea["해외"].str.contains('중국|우한'), "해외"] = '중국'
df_oversea.loc[df_oversea["해외"].str.contains('아랍에미리트'), "해외"] = 'UAE'
df_oversea.loc[df_oversea["해외"].str.contains('필리핀'), "해외"] = '필리핀'
df_oversea.loc[df_oversea["해외"].str.contains('미국'), "해외"] = '미국'

df_oversea["해외"]
# Out:
# 1124        유럽
# 1826        중국
# 4546        유럽
# 4735      네덜란드
# 4924       러시아
#           ...
# 171078     필리핀
# 171084      유럽
# 171167     필리핀
# 171185      유럽
# 171198      유럽
# Name: 해외, Length: 2034, dtype: object

# %%
set(df["여행력"])
# Out:
# {' ',
#  '  ',
#  '-',
#  '21.4.7',
#  'UAE',
#  '가나',
#  '강릉',
#  '과테말라',
#  '괌',
#  '나이지리아',
#  '남미',
#  '남아공',
#  '남아프리카공화국',
#  '네덜란드',
#  '네팔',
#  '덴마크',
#  '도미니카공화국',
#  '독일',
#  '독일 뒤셀도르프',
#  '동남아시아',
#  '두바이',
#  '러브코랄무드',
#  '러시아',
#  '레바논',
#  '루마니아',
#  '르완다',
#  '리투아니아',
#  '마케도니아',
#  '말레이시아',
#  '멕시코',
#  '멕시코(미국경유)',
#  '모로코',
#  '모리셔스',
#  '모리타니아',
#  '몰디브',
#  '몰타',
#  '몽골',
#  '미국',
#  '미국 ',
#  '미국 20년 12월 29일 입국',
#  '미국 아틀란타',
#  '미국 애틀란타',
#  '미국 팔로알퍼',
#  '미국(12.16)',
#  '미국, 중국',
#  '미국LA',
#  '미얀마',
#  '바레인',
#  '방글라데시',
#  '방글라데시,아랍에미리트',
#  '방콕 푸켓',
#  '베네수엘라',
#  '베트남',
#  '베트남 사이공',
#  '벨기에',
#  '북미',
#  '북미, 미국',
#  '불가리아',
#  '불가리아,터키',
#  '브라질',
#  '사우디아라비아',
#  '성석교회 관련 확진자 접촉 추정',
#  '세네갈',
#  '수단',
#  '스리랑카',
#  '스리랑카 ',
#  '스웨덴',
#  '스위스',
#  '스페인',
#  '시에라리온',
#  '싱가포르',
#  '싱가폴',
#  '아랍에미레이트',
#  '아랍에미리트',
#  '아랍에미리트연합',
#  '아르헨티나',
#  '아메리카',
#  '아보카도랩',
#  '아시아',
#  '아이슬란드',
#  '아이티공화국',
#  '아일랜드',
#  '아제르바이잔',
#  '아프가니스탄',
#  '아프리카',
#  '아프리카 아시아',
#  '아프카니스탄',
#  '알제리',
#  '에티오피나',
#  '에티오피아',
#  '영국',
#  '오만',
#  '오세아니아',
#  '오스트리아',
#  '요르단',
#  '우즈베키스탄',
#  '우크라이나',
#  '유럽',
#  '이라크',
#  '이란',
#  '이스라엘',
#  '이집트',
#  '이탈리아',
#  '인도',
#  '인도 ',
#  '인도 델리',
#  '인도네시아',
#  '인도네시아(자카르타 경유)',
#  '인도네시아(자카르타)',
#  '일본',
#  '일본(도쿄)',
#  '자카르타',
#  '잠비아',
#  '조사중',
#  '조지아 터키',
#  '중국',
#  '중국(광저우)',
#  '중국(시안)',
#  '중국(장춘)',
#  '중남미\n유럽',
#  '중동',
#  '중복',
#  '짐바브웨',
#  '천리교 혜성교회 생활관 거주자 집단확진',
#  '체코',
#  '체코 ',
#  '카자흐스탄',
#  '카타르',
#  '캄보디아',
#  '캄보디아(프노펜경유)',
#  '캐나다',
#  '케냐',
#  '코스코 시핑 한국',
#  '코스타리카',
#  '코트디부아르',
#  '코펜하겐',
#  '콜롬비아',
#  '콩고',
#  '콩고민주공화국',
#  '쿠웨이트',
#  '키르기스스탄',
#  '타지키스탄',
#  '탄자니아',
#  '태국',
#  '터키',
#  '파라과이',
#  '파키스탄',
#  '파푸아뉴기니',
#  '파푸아뉴기니(포트모르즈비)',
#  '페루',
#  '포르투갈',
#  '폴란드',
#  '폴란드에서 12.12입국',
#  '프랑스',
#  '프랑스,네델란드',
#  '피지',
#  '핀란드',
#  '필리핀',
#  '필리핀 ',
#  '헝가리',
#  '호주',
#  '홍콩'}

# %%
day_oversea = df_oversea.groupby(["확진일", "해외"])["연번"].count()
day_oversea
# Out:
# 확진일         해외
# 2020-03-04  유럽      1
# 2020-03-07  유럽      1
# 2020-03-09  필리핀     1
# 2020-03-11  유럽      1
# 2020-03-12  유럽      2
#                    ..
# 2021-12-06  네덜란드    1
#             러시아     1
#             유럽      1
# 2021-12-07  유럽      1
#             중국      1
# Name: 연번, Length: 1368, dtype: int64

# %%
df_day_oversea_cumsum = day_oversea.groupby(level=[1]).cumsum()
df_day_oversea_cumsum
# Out:
# 확진일         해외
# 2020-03-04  유럽        1
# 2020-03-07  유럽        2
# 2020-03-09  필리핀       1
# 2020-03-11  유럽        3
# 2020-03-12  유럽        5
#                    ...
# 2021-12-06  네덜란드      8
#             러시아      57
#             유럽      425
# 2021-12-07  유럽      426
#             중국       41
# Name: 연번, Length: 1368, dtype: int64

# %%
df_day_oversea_cumsum = df_day_oversea_cumsum.reset_index()
df_day_oversea_cumsum = df_day_oversea_cumsum.rename(columns={"연번": "누적확진수"})
df_day_oversea_cumsum
# Out:
#             확진일    해외  누적확진수
# 0    2020-03-04    유럽      1
# 1    2020-03-07    유럽      2
# 2    2020-03-09   필리핀      1
# 3    2020-03-11    유럽      3
# 4    2020-03-12    유럽      5
# ...         ...   ...    ...
# 1363 2021-12-06  네덜란드      8
# 1364 2021-12-06   러시아     57
# 1365 2021-12-06    유럽    425
# 1366 2021-12-07    유럽    426
# 1367 2021-12-07    중국     41
#
# [1368 rows x 3 columns]

# %%
oversea_count = df_day_oversea_cumsum["해외"].value_counts().sort_values()
oversea_count_10 =oversea_count.tail(10)

# %%
oversea_count_10.plot.bar(figsize=(10,12))
plt.xticks(rotation = 90)
plt.grid(True)

# %%
oversea_count_gu = df_oversea["거주지"].value_counts()
oversea_count_gu.sort_values().plot.barh(figsize=(10,12))
# Out:
# <AxesSubplot:>

# %%
# 거주지 별 전체 확진자
all_count_gu = df["거주지"].value_counts()
df_all_gu = all_count_gu.to_frame() # 시리즈를 데이터프레임으로 변환 
df_all_gu.columns = ["전체확진수"]


# 거주지 별 여행력을 가진 확진자 
oversea_count_gu = df_oversea["거주지"].value_counts()
df_oversea_gu = oversea_count_gu.to_frame()
df_oversea_gu.columns = ["여행력존재확진수"]

# %%
df_all_oversea_case = df_all_gu.merge(df_oversea_gu, left_index=True, right_index=True)
df_all_oversea_case
# Out:
#       전체확진수  여행력존재확진수
# 송파구   10315        81
# 강남구    9817       181
# 관악구    8760        55
# 타시도    8602        53
# 구로구    8411        39
# 영등포구   8263        57
# 강서구    7846        97
# 은평구    7268        62
# 성북구    7061        87
# 노원구    7048        55
# 강동구    6963        60
# 동대문구   6894        45
# 동작구    6878        92
# 중랑구    6329        33
# 서초구    6319       134
# 양천구    5897        52
# 마포구    5862       145
# 광진구    5510        42
# 강북구    4957        19
# 도봉구    4838        31
# 서대문구   4562        66
# 성동구    4447        46
# 금천구    4403        16
# 용산구    4189       160
# 기타     3704       205
# 종로구    3085        77
# 중구     2964        44

# %%
df_all_oversea_case.sort_values(by="여행력존재확진수").plot.barh(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 정책 단계 수립 3요소
# #### 코로나 일일 확진자 수 , 위중증환자 수 ,  사망자 수
#
# ### 거리두기 단계 숫자데이터로 표현해서 그래프 시각화 가능
